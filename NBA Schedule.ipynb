# %%
#Scraping Schedule

# %%
from bs4 import BeautifulSoup as bs
import requests
import time

import numpy as np
import pandas as pd
from pandas import DataFrame

# %%
# Get html text from a url

## input month ##

url_text = requests.get('https://www.basketball-reference.com/leagues/NBA_2021_games-december.html').text
# *sports reference has a crawl delay of 3 seconds*

#put into beautiful soup
soup = bs(url_text,'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-root="/home/bbr/build" data-version="klecko-" itemscope="" itemtype="https://schema.org/WebSite" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport"/>
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/202012221" rel="dns-prefetch"/>
# <title>2020-21 NBA Schedule and Results | Basketball-Reference.com</title>
# <meta content="League schedule for the 2020-21 NBA season" name="Description"/>
# <link href="https://www.basketball-reference.com/leagues/NBA_2021_games.html" rel="canonical"/>
# <!-- include:start ="/inc/klecko_header_bbr.html_f" -->
# <!-- no:cookie fast load the css.           -->
# ...

# %%
table = soup.find('tbody')
table2 = table.prettify

#table_list = table.find_all('tr')
                  
print(table2)
# Out:
# <bound method Tag.prettify of <tbody>
# <tr><th class="left " csk="202012220BRK" data-stat="date_game" scope="row"><a href="/boxscores/index.fcgi?month=12&amp;day=22&amp;year=2020">Tue, Dec 22, 2020</a></th><td class="right " data-stat="game_start_time">7:00p</td><td class="left " csk="GSW.202012220BRK" data-stat="visitor_team_name"><a href="/teams/GSW/2021.html">Golden State Warriors</a></td><td class="right " data-stat="visitor_pts">99</td><td class="left " csk="BRK.202012220BRK" data-stat="home_team_name"><a href="/teams/BRK/2021.html">Brooklyn Nets</a></td><td class="right " data-stat="home_pts">125</td><td class="center " data-stat="box_score_text"><a href="/boxscores/202012220BRK.html">Box Score</a></td><td class="center iz" data-stat="overtimes"></td><td class="right iz" data-stat="attendance"></td><td class="left iz" data-stat="game_remarks"></td></tr>
# ...

# %%
for th in table.find_all('th'):
    print(th.a.string)
# Out:
# Tue, Dec 22, 2020
# Tue, Dec 22, 2020
# Wed, Dec 23, 2020
# Wed, Dec 23, 2020
# Wed, Dec 23, 2020
# Wed, Dec 23, 2020
# Wed, Dec 23, 2020
# Wed, Dec 23, 2020
# Wed, Dec 23, 2020
# Wed, Dec 23, 2020
# Wed, Dec 23, 2020
# Wed, Dec 23, 2020
# Wed, Dec 23, 2020
# Wed, Dec 23, 2020
# Fri, Dec 25, 2020
# Fri, Dec 25, 2020
# Fri, Dec 25, 2020
# Fri, Dec 25, 2020
# Fri, Dec 25, 2020
# Sat, Dec 26, 2020
# Sat, Dec 26, 2020
# Sat, Dec 26, 2020
# Sat, Dec 26, 2020
# Sat, Dec 26, 2020
# Sat, Dec 26, 2020
# Sat, Dec 26, 2020
# Sat, Dec 26, 2020
# Sat, Dec 26, 2020
# Sat, Dec 26, 2020
# Sun, Dec 27, 2020
# Sun, Dec 27, 2020
# Sun, Dec 27, 2020
# Sun, Dec 27, 2020
# Sun, Dec 27, 2020
# Sun, Dec 27, 2020
# Sun, Dec 27, 2020
# Sun, Dec 27, 2020
# Sun, Dec 27, 2020
# Sun, Dec 27, 2020
# Mon, Dec 28, 2020
# Mon, Dec 28, 2020
# Mon, Dec 28, 2020
# Mon, Dec 28, 2020
# Mon, Dec 28, 2020
# Tue, Dec 29, 2020
# Tue, Dec 29, 2020
# Tue, Dec 29, 2020
# Tue, Dec 29, 2020
# Tue, Dec 29, 2020
# Tue, Dec 29, 2020
# ...

# %%
#print(headers)
print()
for th in headers.find_all('th'):
    cols = th.string
    print(cols)
    # only storing last iteration
# Out:
# Date
# Start (ET)
# Visitor/Neutral
# PTS
# Home/Neutral
# PTS
#
#
# Attend.
# Notes

# %%
sched_df = 

for th in table.find_all('th'):
    print(td.string)
    print(data)
# Out:
# 7:00p
# None
# Golden State Warriors
# None
# 99
# None
# Brooklyn Nets
# None
# 125
# None
# Box Score
# None
# None
# None
# None
# None
# None
# None
# 10:00p
# None
# Los Angeles Clippers
# None
# 116
# None
# Los Angeles Lakers
# None
# 109
# None
# Box Score
# None
# None
# None
# None
# None
# None
# None
# 7:00p
# None
# Charlotte Hornets
# None
# 114
# None
# Cleveland Cavaliers
# None
# 121
# None
# Box Score
# None
# None
# None
# 300
# None
# None
# None
# 7:00p
# None
# New York Knicks
# None
# 107
# None
# Indiana Pacers
# None
# 121
# None
# Box Score
# None
# None
# None
# 0
# None
# None
# None
# 7:00p
# None
# Miami Heat
# None
# 107
# None
# Orlando Magic
# None
# 113
# None
# Box Score
# None
# None
# None
# 3,396
# None
# None
# None
# 7:00p
# None
# Washington Wizards
# None
# 107
# None
# Philadelphia 76ers
# None
# 113
# None
# Box Score
# None
# None
# None
# 0
# None
# None
# None
# 7:30p
# None
# New Orleans Pelicans
# None
# 113
# None
# Toronto Raptors
# ...

# %%
# Out:
#   File "<ipython-input-33-9226514da9a9>", line 1
#     for headers in range(0,length(headers))
#                                            ^
# SyntaxError: invalid syntax

# %%
# Out:
# 21
